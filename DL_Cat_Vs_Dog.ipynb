# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritika-Gada/Machine-Learning-Projects/blob/main/DL_Cat_Vs_Dog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Remember for this to work the json file needs to be taken from the kaggle accounts section.
#
# Now the dataset can be imported from Kaggle

# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# ...
#  99% 803M/812M [00:10<00:00, 118MB/s]
# 100% 812M/812M [00:10<00:00, 80.9MB/s]

# %%
# !ls
# Out:
# dogs-vs-cats.zip  kaggle.json  sample_data

# %%
#extracting the compressed dataset
from zipfile import ZipFile
dataset = '/content/dogs-vs-cats.zip'
with ZipFile(dataset,'r') as zip:
    zip.extractall()
    print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
#extracting the training dataset
dataset = '/content/train.zip'
with ZipFile(dataset,'r') as zip:
    zip.extractall()
    print('The training dataset is extracted')
# Out:
# The training dataset is extracted

# %%
import os
#counting the number of files in the train folder
path, dirs, files = next(os.walk('/content/train'))
file_count = len(files)
print('Number of images: ',file_count)
# Out:
# Number of images:  25000

# %% [markdown]
# Here we printed the number of images

# %%
file_names = os.listdir('/content/train/')
print(file_names)
# Out:
# ['cat.11679.jpg', 'dog.4125.jpg', 'cat.2598.jpg', 'cat.9846.jpg', 'dog.2876.jpg', 'cat.10578.jpg', 'cat.693.jpg', 'cat.3887.jpg', 'cat.10498.jpg', 'dog.2600.jpg', 'cat.2017.jpg', 'cat.697.jpg', 'cat.5264.jpg', 'dog.10004.jpg', 'dog.3753.jpg', 'dog.5054.jpg', 'dog.2366.jpg', 'cat.1235.jpg', 'cat.257.jpg', 'dog.9842.jpg', 'dog.1862.jpg', 'dog.5364.jpg', 'cat.5815.jpg', 'dog.6580.jpg', 'cat.4754.jpg', 'cat.1759.jpg', 'cat.4343.jpg', 'dog.10982.jpg', 'dog.10163.jpg', 'cat.11777.jpg', 'cat.11874.jpg', 'cat.11649.jpg', 'cat.3049.jpg', 'dog.2492.jpg', 'cat.12447.jpg', 'cat.5825.jpg', 'cat.6710.jpg', 'dog.7040.jpg', 'dog.6783.jpg', 'cat.2318.jpg', 'cat.4183.jpg', 'dog.9561.jpg', 'dog.6421.jpg', 'dog.3260.jpg', 'cat.3697.jpg', 'dog.2890.jpg', 'dog.2304.jpg', 'cat.7604.jpg', 'cat.9429.jpg', 'dog.6655.jpg', 'dog.3220.jpg', 'dog.1006.jpg', 'cat.1611.jpg', 'cat.12030.jpg', 'dog.10195.jpg', 'cat.11960.jpg', 'cat.10355.jpg', 'cat.4185.jpg', 'dog.8113.jpg', 'dog.5900.jpg', 'cat.5054.jpg', 'dog.7257.
# ...

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
from google.colab.patches import cv2_imshow

# %% [markdown]
# Displaying the image of dogs and cats

# %%
#display dog image
img = mpimg.imread('/content/train/dog.8298.jpg')
imgplt = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('/content/train/cat.4352.jpg')
implt = plt.imshow(img)
plt.show()

# %%
file_names = os.listdir('/content/train/')
for i in range(5):
    name = file_names[i]
    print(name[0:3])
# Out:
# cat
# dog
# cat
# cat
# dog

# %%
file_names = os.listdir('/content/train/')
dog_count = 0
cat_count = 0

for img_file in file_names:
    name = img_file[0:3]

    if name == 'dog':
        dog_count += 1
    else:
        cat_count += 1

print('Number of dog images: ',dog_count)
print('Number of cat images: ',cat_count)
# Out:
# Number of dog images:  12500
# Number of cat images:  12500

# %% [markdown]
# Resizing all the images

# %%
#creating a directory for resized images
os.mkdir('/content/image resized')

# %%
original_folder = '/content/train/'
resized_folder = '/content/image resized/'

for i in range(2000):
    filename = os.listdir(original_folder)[i]
    img_path = original_folder+filename

    img = Image.open(img_path)
    img = img.resize((224,224))
    img = img.convert('RGB')

    newImgPath = resized_folder+filename
    img.save(newImgPath)

# %%
#display resized dog image
img = mpimg.imread('/content/image resized/dog.4125.jpg')
imgplt = plt.imshow(img)
plt.show()

# %%
# display resized cat image
img = mpimg.imread('/content/image resized/cat.693.jpg')
imgplt = plt.imshow(img)
plt.show()

# %% [markdown]
# **Creating labels for resized images of dogs and cats**
#
# Cat --> 0
# Dog --> 1

# %%
#creating a 'for loop' to assign labels
filenames= os.listdir('/content/image resized/')

labels = []

for i in range(2000):
    file_name = filenames[i]
    label = file_name[0:3]

    if label == 'dog':
        labels.append(1)
    else:
        labels.append(0)

# %%
print(filenames[0:5])
print(len(filenames))
# Out:
# ['cat.11679.jpg', 'dog.4125.jpg', 'cat.2598.jpg', 'cat.9846.jpg', 'dog.2876.jpg']
# 2000

# %%
print(labels[0:5])
print(len(labels))
# Out:
# [0, 1, 0, 0, 1]
# 2000

# %%
# counting the images of dogs and cats out of 2000 images
values, counts = np.unique(labels, return_counts=True)
print(values)
print(counts)
# Out:
# [0 1]
# [ 998 1002]

# %% [markdown]
# Now we will convert all the resized images to numpy arrays

# %%
import cv2
import glob

# %%
image_directory = '/content/image resized/'
image_extension = ['png','jpg']

files = []

[files.extend(glob.glob(image_directory + '*.' + e)) for e in image_extension]

dog_cat_images = np.asarray([cv2.imread(file) for file in files])

# %%
print(dog_cat_images)
# Out:
# [[[[157 203 227]
#    [157 203 227]
#    [157 203 227]
#    ...
#    [159 202 229]
#    [159 202 229]
#    [159 202 229]]
#
#   [[157 203 227]
#    [157 203 227]
#    [157 203 227]
#    ...
#    [160 203 230]
#    [160 203 230]
#    [160 203 230]]
#
#   [[157 203 227]
#    [157 203 227]
#    [157 203 227]
#    ...
#    [162 205 232]
#    [162 205 232]
#    [162 205 232]]
#
#   ...
#
#   [[ 51  55  60]
#    [ 45  49  54]
#    [ 38  42  47]
#    ...
#    [ 23  26  30]
#    [ 23  26  30]
#    [ 42  45  49]]
#
#   [[ 53  57  62]
#    [ 36  40  45]
#    [ 44  48  53]
#    ...
#    [ 34  37  41]
#    [ 17  20  24]
#    [ 33  36  40]]
#
#   [[ 55  59  64]
#    [ 31  35  40]
#    [ 49  53  58]
#    ...
#    [ 42  45  49]
#    [ 14  17  21]
#    [ 28  31  35]]]
#
#
#  [[[ 88  79  82]
#    [ 88  79  82]
#    [ 88  79  82]
#    ...
#    [120 108  96]
#    [122 110  98]
#    [124 112 100]]
#
#   [[ 87  78  81]
#    [ 87  78  81]
#    [ 87  78  81]
#    ...
#    [120 108  96]
#    [121 109  97]
# ...

# %%
type(dog_cat_images)
# Out:
# numpy.ndarray

# %%
print(dog_cat_images.shape)
# Out:
# (2000, 224, 224, 3)

# %%
X = dog_cat_images
Y = np.asarray(labels)

# %% [markdown]
# **Train Test Split**

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,Y,test_size=0.2, random_state=2)

# %%
print(X.shape, xtrain.shape,xtest.shape)
# Out:
# (2000, 224, 224, 3) (1600, 224, 224, 3) (400, 224, 224, 3)

# %%
xtrain_scaled = xtrain/255
xtest_scaled = xtest/255

# %%
print(xtrain_scaled)
# Out:
# [[[[0.61960784 0.65098039 0.65098039]
#    [0.62352941 0.65490196 0.65490196]
#    [0.62745098 0.65882353 0.65882353]
#    ...
#    [0.6        0.60784314 0.60784314]
#    [0.59607843 0.60392157 0.60392157]
#    [0.59215686 0.6        0.6       ]]
#
#   [[0.61960784 0.65098039 0.65098039]
#    [0.62352941 0.65490196 0.65490196]
#    [0.62745098 0.65882353 0.65882353]
#    ...
#    [0.6        0.60784314 0.60784314]
#    [0.6        0.60784314 0.60784314]
#    [0.6        0.60784314 0.60784314]]
#
#   [[0.61960784 0.65098039 0.65098039]
#    [0.62352941 0.65490196 0.65490196]
#    [0.62745098 0.65882353 0.65882353]
#    ...
#    [0.60392157 0.61176471 0.61176471]
#    [0.60784314 0.61568627 0.61568627]
#    [0.61176471 0.61960784 0.61960784]]
#
#   ...
#
#   [[0.15294118 0.2        0.27058824]
#    [0.17254902 0.21960784 0.29019608]
#    [0.17647059 0.22352941 0.29411765]
#    ...
#    [0.79215686 0.81176471 0.80784314]
#    [0.76078431 0.78431373 0.78039216]
# ...

# %% [markdown]
# **Building the Neural Network**

# %%
import tensorflow as tf
import tensorflow_hub as hub

# %%
mobilenet_model = 'https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4'

pretrained_model = hub.KerasLayer(mobilenet_model, input_shape=(224,224,3), trainable=False)

# %%
num_of_classes = 2
model = tf.keras.Sequential([
    pretrained_model,
    tf.keras.layers.Dense(num_of_classes)
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  keras_layer (KerasLayer)    (None, 1280)              2257984
#
#  dense (Dense)               (None, 2)                 2562
#
# ...
# Total params: 2260546 (8.62 MB)
# Trainable params: 2562 (10.01 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
    metrics = ['acc']
)

# %%
model.fit(xtrain_scaled,ytrain,epochs=5)
# Out:
# Epoch 1/5
# 50/50 [==============================] - 71s 1s/step - loss: 0.2160 - acc: 0.9100
# Epoch 2/5
# 50/50 [==============================] - 68s 1s/step - loss: 0.0758 - acc: 0.9731
# Epoch 3/5
# 50/50 [==============================] - 62s 1s/step - loss: 0.0573 - acc: 0.9819
# Epoch 4/5
# 50/50 [==============================] - 67s 1s/step - loss: 0.0432 - acc: 0.9862
# Epoch 5/5
# 50/50 [==============================] - 63s 1s/step - loss: 0.0363 - acc: 0.9894

# %%
score, acc = model.evaluate(xtest_scaled,ytest)
# Out:
# 13/13 [==============================] - 29s 2s/step - loss: 0.0660 - acc: 0.9775

# %%
print('Test Loss =', score)
print('Test Accuracy =', acc)
# Out:
# Test Loss = 0.06604080647230148
# Test Accuracy = 0.9775000214576721

# %% [markdown]
# **Predictive System**

# %%
input_image_path = input('Path of the image to be predicted: ')
input_image = cv2.imread(input_image_path)

cv2_imshow(input_image)

input_image_resize = cv2.resize(input_image, (224,224))

input_image_scaled = input_image_resize/255

image_reshaped = np.reshape(input_image_scaled, [1,224,224,3])

input_prediction = model.predict(image_reshaped)

print(input_prediction)

input_pred_label = np.argmax(input_prediction)

print(input_pred_label)

if input_pred_label == 0:
    print('The image represents a Cat')
else:
    print('The image represents a Dog')
# Out:
# Path of the image to be predicted: /content/cat.jpg
# <PIL.Image.Image image mode=RGB size=225x225>
# 1/1 [==============================] - 1s 576ms/step
# [[ 3.732298  -4.5755453]]
# 0
# The image represents a Cat

# %%
input_image_path = input('Path of the image to be predicted: ')
input_image = cv2.imread(input_image_path)

cv2_imshow(input_image)

input_image_resize = cv2.resize(input_image, (224,224))

input_image_scaled = input_image_resize/255

image_reshaped = np.reshape(input_image_scaled, [1,224,224,3])

input_prediction = model.predict(image_reshaped)

print(input_prediction)

input_pred_label = np.argmax(input_prediction)

print(input_pred_label)

if input_pred_label == 0:
    print('The image represents a Cat')
else:
    print('The image represents a Dog')
# Out:
# Path of the image to be predicted: /content/dog.jpg
# <PIL.Image.Image image mode=RGB size=299x168>
# 1/1 [==============================] - 0s 48ms/step
# [[-2.9864824  2.190028 ]]
# 1
# The image represents a Dog
